# %%
#import os
#os.system('sh marcap.sh')

# !sh marcap.sh
# Out:
# Already up to date.

# %%
"""
# 
import subprocess
pwd = subprocess.Popen("pwd", shell=True, stdout=subprocess.PIPE).stdout
curr_dir = pwd.read().decode().rstrip()
curr_dir
"""

# extract filename and extension
import os
fullpath = '/Users/jkkim/workspace/python/stock/my/download/21_1Q_종합순위_220605_162809.xlsx'
directory = fullpath[:fullpath.rindex('/')]
filename, ext = os.path.splitext(os.path.basename(fullpath))

"""
import datetime
from marcap import marcap_data

yymmdd = filename.split('_')[-2]
next = datetime.datetime.strptime(yymmdd, '%y%m%d')
yyyymmdd = next.strftime('%Y-%m-%d')
result = marcap_data(yyyymmdd)
while len(result) <= 0:
    next = next + datetime.timedelta(days=-1)
    yyyymmdd = next.strftime('%Y-%m-%d')
    result = marcap_data(yyyymmdd)

#result
"""

import FinanceDataReader as fdr

krx = fdr.StockListing('KRX')
krx
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 7819  003280   KOSPI             흥아해운                    해상 운송업
# 7820  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7821  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7822  429870   KOSPI    히어로즈 리츠이지스액티브                       NaN
# 7823  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# ...

# %%
import pandas as pd
old = pd.read_excel(fullpath)
old

# modify table (add column,...)

# overwrite the file

#import os
#import datetime
#from my.utils import ( format_time_from_seconds )

#curr_dir = os.path.dirname(os.path.abspath(__file__))
# Out:
#       Unnamed: 0    종목코드         종목명         기준일           시가총액      상장주식수  \
# 0             37   17940          E1  2021-04-01   295666000000    6860000
# 1            815    4690         삼천리  2021-04-01   317913960000    4055025
# 2             25   16610      DB금융투자  2021-04-01   257649581230   42446389
# 3            214  267290      경동도시가스  2021-04-01   116434268500    5895406
# 4           2062   88350        한화생명  2021-04-01  2727184200000  868530000
# ...          ...     ...         ...         ...            ...        ...
# 2137        2068  340440  한화플러스제1호스팩  2021-04-01     9749700000    4710000
# 2138        2070   34810        해성산업  2021-04-01   426972027600   26356298
# 2139        2085  319400       현대무벡스  2021-04-01   463345185820  101722324
# 2140        2117  378850      화승알앤에이  2021-04-01   104274990270   18993623
# 2141        2159  238490          힘스  2021-04-01   151583962400   11312236
#
# ...
